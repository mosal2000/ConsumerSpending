# %%
import requests
import json
import pprint as pp
import pandas as pd
from laborstat import BLSservice

# %% [markdown]
# # Entertainment Overall Total

# %%
overall = BLSservice([ 'CXUENTRTAINLB1201M',
                        'CXUENTRTAINLB1202M',
                        'CXUENTRTAINLB1203M',
                        'CXUENTRTAINLB1204M',
                        'CXUENTRTAINLB1205M',
                        'CXUENTRTAINLB1206M',
                        'CXUENTRTAINLB1207M',
                        'CXUENTRTAINLB1208M',
                        'CXUENTRTAINLB1209M',
                        'CXUENTRTAINLB1210M'
                     ], '2017', '2017')

# %%
overall.get_data()
overall.create_dataframe()

# %%
overall.item_df
# Out:
#                                          SeriesTitle Value  Year
# 0                                 All Consumer Units  3203  2017
# 1                              Self-employed workers  4834  2017
# 2                      Total wage and salary earners  3406  2017
# 3  Wage & salary earners: managers and professionals  4561  2017
# 4  Wage & salary: tech., sales, and clerical workers  2923  2017
# 5             Wage & salary earners: service workers  2265  2017
# 6    Wage & salary: construction workers & mechanics  2597  2017
# 7   Wage & salary: Operators, fabricators & laborers  2694  2017
# 8                                            Retired  2726  2017
# 9     Occupation: all other, including not reporting  2206  2017

# %%
overall.transposed_item_df
# Out:
#                               0                      1  \
# SeriesTitle  All Consumer Units  Self-employed workers
# Value                      3203                   4834
# Year                       2017                   2017
#
#                                          2  \
# SeriesTitle  Total wage and salary earners
# Value                                 3406
# Year                                  2017
#
#                                                              3  \
# SeriesTitle  Wage & salary earners: managers and professionals
# Value                                                     4561
# Year                                                      2017
#
#                                                              4  \
# SeriesTitle  Wage & salary: tech., sales, and clerical workers
# Value                                                     2923
# Year                                                      2017
#
# ...

# %%
overall.clean_df
# Out:
#                               0                      1  \
# SeriesTitle  All Consumer Units  Self-employed workers
# Value                      3203                   4834
#
#                                          2  \
# SeriesTitle  Total wage and salary earners
# Value                                 3406
#
#                                                              3  \
# SeriesTitle  Wage & salary earners: managers and professionals
# Value                                                     4561
#
#                                                              4  \
# SeriesTitle  Wage & salary: tech., sales, and clerical workers
# Value                                                     2923
#
#                                                   5  \
# SeriesTitle  Wage & salary earners: service workers
# Value                                          2265
#
#                                                            6  \
# ...

# %%
overall.create_excel_file_from_clean_df("Overall.xlsx")

# %% [markdown]
# # Entertainment: fees and admissions

# %%
fees_admin = BLSservice([ 'CXUFEESADMLB1201M',
                          'CXUFEESADMLB1202M',
                          'CXUFEESADMLB1203M',
                          'CXUFEESADMLB1204M',
                          'CXUFEESADMLB1205M',
                          'CXUFEESADMLB1206M',
                          'CXUFEESADMLB1207M',
                          'CXUFEESADMLB1208M',
                          'CXUFEESADMLB1209M',
                          'CXUFEESADMLB1210M'
                         ], '2017', '2017')

# %%
fees_admin.get_data()
fees_admin.create_dataframe()
fees_admin.item_df
# Out:
#                                          SeriesTitle Value  Year
# 0                                 All Consumer Units   750  2017
# 1                              Self-employed workers  1172  2017
# 2                      Total wage and salary earners   826  2017
# 3  Wage & salary earners: managers and professionals  1330  2017
# 4  Wage & salary: tech., sales, and clerical workers   554  2017
# 5             Wage & salary earners: service workers   497  2017
# 6    Wage & salary: construction workers & mechanics   402  2017
# 7   Wage & salary: Operators, fabricators & laborers   323  2017
# 8                                            Retired   572  2017
# 9     Occupation: all other, including not reporting   479  2017

# %%
fees_admin.transposed_item_df
# Out:
#                               0                      1  \
# SeriesTitle  All Consumer Units  Self-employed workers
# Value                       750                   1172
# Year                       2017                   2017
#
#                                          2  \
# SeriesTitle  Total wage and salary earners
# Value                                  826
# Year                                  2017
#
#                                                              3  \
# SeriesTitle  Wage & salary earners: managers and professionals
# Value                                                     1330
# Year                                                      2017
#
#                                                              4  \
# SeriesTitle  Wage & salary: tech., sales, and clerical workers
# Value                                                      554
# Year                                                      2017
#
# ...

# %%
fees_admin.clean_df
# Out:
#                               0                      1  \
# SeriesTitle  All Consumer Units  Self-employed workers
# Value                       750                   1172
#
#                                          2  \
# SeriesTitle  Total wage and salary earners
# Value                                  826
#
#                                                              3  \
# SeriesTitle  Wage & salary earners: managers and professionals
# Value                                                     1330
#
#                                                              4  \
# SeriesTitle  Wage & salary: tech., sales, and clerical workers
# Value                                                      554
#
#                                                   5  \
# SeriesTitle  Wage & salary earners: service workers
# Value                                           497
#
#                                                            6  \
# ...

# %%
fees_admin.create_excel_file_from_clean_df("Fees_Admin.xlsx")

# %% [markdown]
# # Entertainment: Audio and visual equipment and services

# %%
tv_audio = BLSservice(['CXUTVAUDIOLB1201M',
                       'CXUTVAUDIOLB1202M',
                       'CXUTVAUDIOLB1203M',
                       'CXUTVAUDIOLB1204M',
                       'CXUTVAUDIOLB1205M',
                       'CXUTVAUDIOLB1206M',
                       'CXUTVAUDIOLB1207M',
                       'CXUTVAUDIOLB1208M',
                       'CXUTVAUDIOLB1209M',
                       'CXUTVAUDIOLB1210M'
                      ], '2017', '2017')

# %%
tv_audio.get_data()
tv_audio.create_dataframe()
tv_audio.item_df
# Out:
#                                          SeriesTitle Value  Year
# 0                                 All Consumer Units   985  2017
# 1                              Self-employed workers  1143  2017
# 2                      Total wage and salary earners  1017  2017
# 3  Wage & salary earners: managers and professionals  1238  2017
# 4  Wage & salary: tech., sales, and clerical workers   923  2017
# 5             Wage & salary earners: service workers   785  2017
# 6    Wage & salary: construction workers & mechanics   956  2017
# 7   Wage & salary: Operators, fabricators & laborers   878  2017
# 8                                            Retired   952  2017
# 9     Occupation: all other, including not reporting   808  2017

# %%
tv_audio.transposed_item_df
# Out:
#                               0                      1  \
# SeriesTitle  All Consumer Units  Self-employed workers
# Value                       985                   1143
# Year                       2017                   2017
#
#                                          2  \
# SeriesTitle  Total wage and salary earners
# Value                                 1017
# Year                                  2017
#
#                                                              3  \
# SeriesTitle  Wage & salary earners: managers and professionals
# Value                                                     1238
# Year                                                      2017
#
#                                                              4  \
# SeriesTitle  Wage & salary: tech., sales, and clerical workers
# Value                                                      923
# Year                                                      2017
#
# ...

# %%
tv_audio.clean_df
# Out:
#                               0                      1  \
# SeriesTitle  All Consumer Units  Self-employed workers
# Value                       985                   1143
#
#                                          2  \
# SeriesTitle  Total wage and salary earners
# Value                                 1017
#
#                                                              3  \
# SeriesTitle  Wage & salary earners: managers and professionals
# Value                                                     1238
#
#                                                              4  \
# SeriesTitle  Wage & salary: tech., sales, and clerical workers
# Value                                                      923
#
#                                                   5  \
# SeriesTitle  Wage & salary earners: service workers
# Value                                           785
#
#                                                            6  \
# ...

# %% [markdown]
# # Entertainment: Pets

# %%
pets = BLSservice(['CXUPETSLB1201M',
                   'CXUPETSLB1202M',
                   'CXUPETSLB1203M',
                   'CXUPETSLB1204M',
                   'CXUPETSLB1205M',
                   'CXUPETSLB1206M',
                   'CXUPETSLB1207M',
                   'CXUPETSLB1208M',
                   'CXUPETSLB1209M',
                   'CXUPETSLB1210M'
                  ], '2017', '2017')

# %%
pets.get_data()
pets.create_dataframe()
pets.item_df
# Out:
#                                          SeriesTitle Value  Year
# 0                                 All Consumer Units   710  2017
# 1                              Self-employed workers  1737  2017
# 2                      Total wage and salary earners   690  2017
# 3  Wage & salary earners: managers and professionals   923  2017
# 4  Wage & salary: tech., sales, and clerical workers   575  2017
# 5             Wage & salary earners: service workers   380  2017
# 6    Wage & salary: construction workers & mechanics   511  2017
# 7   Wage & salary: Operators, fabricators & laborers   763  2017
# 8                                            Retired   585  2017
# 9     Occupation: all other, including not reporting   510  2017

# %%
pets.transposed_item_df
# Out:
#                               0                      1  \
# SeriesTitle  All Consumer Units  Self-employed workers
# Value                       710                   1737
# Year                       2017                   2017
#
#                                          2  \
# SeriesTitle  Total wage and salary earners
# Value                                  690
# Year                                  2017
#
#                                                              3  \
# SeriesTitle  Wage & salary earners: managers and professionals
# Value                                                      923
# Year                                                      2017
#
#                                                              4  \
# SeriesTitle  Wage & salary: tech., sales, and clerical workers
# Value                                                      575
# Year                                                      2017
#
# ...

# %%
pets.clean_df
# Out:
#                               0                      1  \
# SeriesTitle  All Consumer Units  Self-employed workers
# Value                       710                   1737
#
#                                          2  \
# SeriesTitle  Total wage and salary earners
# Value                                  690
#
#                                                              3  \
# SeriesTitle  Wage & salary earners: managers and professionals
# Value                                                      923
#
#                                                              4  \
# SeriesTitle  Wage & salary: tech., sales, and clerical workers
# Value                                                      575
#
#                                                   5  \
# SeriesTitle  Wage & salary earners: service workers
# Value                                           380
#
#                                                            6  \
# ...
